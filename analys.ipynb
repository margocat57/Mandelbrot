# %% [markdown]
# # Анализ оптимизаций алгоритма построения множества Мальдеброта

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

df = pd.read_csv("results.csv", header=None, sep=";")

# %% [markdown]
# ## Наивная реализация запуск на g++ (-O2)

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O2)")
plt.show()

# %%
subset1_2_g = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++" )
]

subset1_2_g.describe()
# Out:
#                3
# count  90.000000
# mean    4.089178
# std     0.000549
# min     4.088300
# 25%     4.088872
# 50%     4.089095
# 75%     4.089303
# max     4.091240

# %%
mean = np.mean(subset1_2_g.iloc[:,3])
std = np.std(subset1_2_g.iloc[:,3], ddof=1)
n = len(subset1_2_g.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 4.0890642900175385 4.089291043315794

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (g++ -O2) от 4.0891 до 4.0893 секунд, среднее время работы 4.0892 секунд

# %% [markdown]
# ## Наивная реализация запуск на clang++ (-O2)

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O2)")
plt.show()

# %%
subset1_2_c = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++" )
]

subset1_2_c.describe()
# Out:
#                3
# count  90.000000
# mean    4.026069
# std     0.000439
# min     4.025040
# 25%     4.025762
# 50%     4.026095
# 75%     4.026265
# max     4.027870

# %%
mean = np.mean(subset1_2_c.iloc[:,3])
std = np.std(subset1_2_c.iloc[:,3], ddof=1)
n = len(subset1_2_c.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 4.025977957967976 4.0261591531431336

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (clang++ -O2) от 4.0260 до 4.0262 секунд, среднее время работы 4.0261 секунд

# %% [markdown]
# ## Наивная реализация запуск на g++ (-O3)

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O3)")
plt.show()

# %%
subset1_3_g = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++" )
]

subset1_3_g.describe()
# Out:
#                3
# count  90.000000
# mean    4.089529
# std     0.000392
# min     4.088820
# 25%     4.089260
# 50%     4.089495
# 75%     4.089760
# max     4.090830

# %%
mean = np.mean(subset1_3_g.iloc[:,3])
std = np.std(subset1_3_g.iloc[:,3], ddof=1)
n = len(subset1_3_g.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 4.089447598010752 4.089609735322583

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (g++ -O3) от 4.0894 до 4.0896 секунд, среднее время работы 4.0895 секунд

# %% [markdown]
# ## Наивная реализация запуск на clang++ (-O3)

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O3)")
plt.show()

# %%
subset1_3_c = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++" )
]


subset1_3_c.describe()
# Out:
#                3
# count  90.000000
# mean    4.026425
# std     0.000534
# min     4.025380
# 25%     4.026033
# 50%     4.026430
# 75%     4.026842
# max     4.028040

# %%
mean = np.mean(subset1_3_c.iloc[:,3])
std = np.std(subset1_3_c.iloc[:,3], ddof=1)
n = len(subset1_3_c.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 4.0263149648851835 4.02653547955926

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (clang++ -O2) от 4.0263 до 4.0265 секунд, среднее время работы 4.0264 секунд

# %% [markdown]
# ### Сравнение всех оптимизаций для наивной реализации

# %% [markdown]
# | Компилятор/Оптимизация | Naive |
# |------------------------|---------------|
# | g++ -O2                |  4.0892 (+- 0.0005)    |
# | g++ -O3                |  4.0895 (+- 0.0004) |
# | clang++ -O2            |  4.0261 (+- 0.0004)     |
# | clang++ -O3            |  4.0264 (+- 0.0005)    |

# %%
filtered = df[df.iloc[:,0] == "mandelbrot1"]

sns.barplot(
    data=filtered,
    x=filtered.iloc[:,2],   
    y=filtered.iloc[:,3],  
    hue=filtered.iloc[:,1],
    ci="sd"                 
)

plt.xlabel("Флаг оптимизации")
plt.title("Среднее время работы для 100 генераций вычисления множества Мандельброта")
plt.show()
# Out:
# /tmp/ipykernel_7711/302414564.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # Объяснение разницы работы реализаций
#
# ## G++ vs clang++ флаг -О2
#
# Основное различие заключается в том, что g++ не разворачивает циклы, а clang++ - разворачивает.
#
# g++ :
#
# <img src="godbolt_img/1_2.png" width="80%">
#
# clang++:
#
# <img src="godbolt_img/1_2_cyc.png" width="80%">
#
# Также g++ более экономно использует регистры и сильнее обращается память (даже внутри циклов) в отличие от clang++ - он сильнее использует регистры, а все обращение в память старается вынести вне циклов. Особенно это можно видеть если посмотреть на ассемберный код, сгенерированный компиляторами для
# ```c
# double y0 = ((i_for_y - (double)SUPER_HEIGHT / 2) * DY) * SCALE_Y * params->zoom + params->center_y;
# ```
#
# g++ :
#
# <img src="godbolt_img/1_1gcc.png" width="80%">
#
# clang++:
#
# <img src="godbolt_img/1_1clang.png" width="80%">
#
# ## G++ и clang++ -O3 vs -O2
#
# Различий нет, так как код, сгенерированный при данных оптимизациях не отличается от кода сгенерированного при -О2. Однако

# %% [markdown]
# ## Реализация на массивах запуск на g++ с флагом -O2

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=7,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O2)")
plt.show()

# %%
subset2_2_g = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++" )
]

subset2_2_g.describe()
# Out:
#                3
# count  90.000000
# mean    1.648914
# std     0.002400
# min     1.645740
# 25%     1.646670
# 50%     1.648465
# 75%     1.650425
# max     1.656070

# %%
mean = np.mean(subset2_2_g.iloc[:,3])
std = np.std(subset2_2_g.iloc[:,3], ddof=1)
n = len(subset2_2_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.6484181598344692 1.6494098401655313

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (g++ -O2) от 1.648 до 1.649 секунд, среднее время работы 1.649 секунд

# %% [markdown]
# ## Реализация на массивах запуск на clang++ с флагом -O2

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O2)")
plt.show()

# %%
subset2_2_c = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++" )
]

subset2_2_c.describe()
# Out:
#                3
# count  90.000000
# mean    1.498450
# std     0.000641
# min     1.497680
# 25%     1.498025
# 50%     1.498190
# 75%     1.498830
# max     1.500800

# %%
mean = np.mean(subset2_2_c.iloc[:,3])
std = np.std(subset2_2_c.iloc[:,3], ddof=1)
n = len(subset2_2_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.4983180624034713 1.498582826485417

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (clang++ -O2) от 1.4983 до 1.4985 секунд, среднее время работы 1.4985 секунд

# %% [markdown]
# ## Реализация на массивах запуск на g++ с флагом -O3

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O3)")
plt.show()

# %%
subset2_3_g = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++" )
]

subset2_3_g.describe()
# Out:
#                3
# count  90.000000
# mean    2.076842
# std     0.001245
# min     2.074430
# 25%     2.075673
# 50%     2.077055
# 75%     2.077705
# max     2.080000

# %%
mean = np.mean(subset2_3_g.iloc[:,3])
std = np.std(subset2_3_g.iloc[:,3], ddof=1)
n = len(subset2_3_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 2.0765844073331645 2.077098926000168

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (g++ -O3) от 2.077 до 2.077 секунд, среднее время работы 2.077 секунд

# %% [markdown]
# ## Реализация на массивах запуск на clang++ с флагом -O3

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O3)")
plt.show()

# %%
subset2_3_c = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++" )
]

subset2_3_c.describe()
# Out:
#                3
# count  90.000000
# mean    1.498242
# std     0.000726
# min     1.493000
# 25%     1.497910
# 50%     1.498185
# 75%     1.498708
# max     1.499760

# %%
mean = np.mean(subset2_3_c.iloc[:,3])
std = np.std(subset2_3_c.iloc[:,3], ddof=1)
n = len(subset2_3_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.498092517851646 1.4983923710372433

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (clang++ -O3) от 1.4981 до 1.4984 секунд, среднее время работы 1.4982 секунд

# %% [markdown]
# ### Сравнений всех оптимизаций для реализации на массивах

# %% [markdown]
# | Компилятор/Оптимизация | Array |
# |------------------------|---------------|
# | g++ -O2                |  1.649 (+- 0.002)  |
# | g++ -O3                |  2.077 (+- 0.001)     |
# | clang++ -O2            |  1.4985 (+- 0.0006)    |
# | clang++ -O3            |  1.4982 (+- 0.0007)    |

# %%
filtered = df[df.iloc[:,0] == "mandelbrot2"]

sns.barplot(
    data=filtered,
    x=filtered.iloc[:,2],   
    y=filtered.iloc[:,3],  
    hue=filtered.iloc[:,1],
    ci="sd"                 
)

plt.xlabel("Флаг оптимизации")
plt.title("Среднее время работы для 100 генераций вычисления множества Мандельброта")
plt.show()
# Out:
# /tmp/ipykernel_7711/193063319.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # Объяснение разницы работы реализаций
#
# ## G++ vs clang++ флаг -О2
#
# Clang++ активнее использует fma и simd инструкции и меньше обращается к памяти в циклах, например для
#
# ```c
# for(int j = 0; j < 4; j++){x0[j]= X0 + j*dx;};
# ```
#
# clang++ заменил на SIMD вариант, а g++ - нет и при этом обращается в память.
#
# g++ :
#
# <img src="godbolt_img/2_2gcc.png" width="80%">
#
# clang++:
#
# <img src="godbolt_img/2_2clang.png" width="80%">
#
# Также clang++ на данном уровне оптимизации развернул циклы в отличие от g++
#
# g++ :
#
# <img src="godbolt_img/2_3gcc.png" width="80%">
#
# clang++:
#
# <img src="godbolt_img/2_3clang.png" width="80%">
#
# ## G++ -O2 vs g++ -О3
#
# Intrinsic инструкции стали применяться реже, также стало больше обращений в память, примеры на скриншотах. Например, для
#
# ```c
# for(int j = 0; j < 4; j++){x2[j]= x[j] * x[j];}  (1)
#
# for(int j = 0; j < 4; j++){y2[j]= y[j] * y[j];}
# ```
# g++ на уровне оптимизации -O3 заменил одну intrinsic инструкцию на 4 умножения и одно обращения в память
#
# g++ -O2 :
#
# <img src="godbolt_img/2_4gcc.png" width="80%">
#
# g++ -O3 :
#
# <img src="godbolt_img/2_4c.png" width="80%">

# %% [markdown]
# ## Реализация SIMD запуск на g++ с флагом -O2

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O2)")
plt.show()

# %%
subset3_2_g = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++" )
]


subset3_2_g.describe()
# Out:
#                3
# count  90.000000
# mean    1.248405
# std     0.002645
# min     1.225250
# 25%     1.248193
# 50%     1.248395
# 75%     1.248695
# max     1.252350

# %%
mean = np.mean(subset3_2_g.iloc[:,3])
std = np.std(subset3_2_g.iloc[:,3], ddof=1)
n = len(subset3_2_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.2478587391405713 1.248951483081651

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(g++ -O2) от 1.248 до 1.249 секунд, среднее время работы 1.248 секунд

# %% [markdown]
# ## Реализация SIMD запуск на clang++ с флагом -O2

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O2)")
plt.show()

# %%
subset3_2_c = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++" )
]

subset3_2_c.describe()
# Out:
#                3
# count  90.000000
# mean    1.230594
# std     0.000761
# min     1.229500
# 25%     1.230065
# 50%     1.230250
# 75%     1.231145
# max     1.232650

# %%
mean = np.mean(subset3_2_c.iloc[:,3])
std = np.std(subset3_2_c.iloc[:,3], ddof=1)
n = len(subset3_2_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.2304368357739344 1.230751386448288

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(clang++ -O2) от 1.2304 до 1.2308 секунд, среднее время работы 1.2306 секунд

# %% [markdown]
# ## Реализация SIMD запуск на g++ с флагом -O3

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O3)")
plt.show()

# %%
subset3_3_g = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++" )
]

subset3_3_g.describe()
# Out:
#                3
# count  90.000000
# mean    1.248885
# std     0.001264
# min     1.247450
# 25%     1.248155
# 50%     1.248425
# 75%     1.248857
# max     1.252770

# %%
mean = np.mean(subset3_3_g.iloc[:,3])
std = np.std(subset3_3_g.iloc[:,3], ddof=1)
n = len(subset3_3_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.248623725346827 1.249146052430951

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(g++ -O3) от 1.249 до 1.249 секунд, среднее время работы 1.249 секунд

# %% [markdown]
# ## Реализация SIMD запуск на clang++ с флагом -O3

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++")
]

sns.histplot(
    data=filtered,
    x=filtered.iloc[:,3],
    bins=10,
    stat="density",
    color="skyblue",
    alpha=0.6
)

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    color="red",
    linewidth=2
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O3)")
plt.show()

# %%
subset3_3_c = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++" )
]

subset3_3_c.describe()
# Out:
#                3
# count  90.000000
# mean    1.230789
# std     0.000594
# min     1.229970
# 25%     1.230402
# 50%     1.230645
# 75%     1.231080
# max     1.232830

# %%
mean = np.mean(subset3_3_c.iloc[:,3])
std = np.std(subset3_3_c.iloc[:,3], ddof=1)
n = len(subset3_3_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.2306666249457026 1.230912041720964

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(clang++ -O3) от 1.2307 до 1.2309 секунд, среднее время работы 1.2308 секунд

# %% [markdown]
# ### Сравнений всех оптимизаций для SIMD реализации

# %% [markdown]
# | Компилятор/Оптимизация |         SIMD             |
# |------------------------|---------------------------|
# | g++ -O2                | 1.248 (+- 0.003)  |
# | g++ -O3                | 1.249 (+- 0.001)  |
# | clang++ -O2            | 1.2306 (+- 0.0007) |
# | clang++ -O3            | 1.2308 (+- 0.0006)  |

# %%
filtered = df[df.iloc[:,0] == "mandelbrot3"]

sns.barplot(
    data=filtered,
    x=filtered.iloc[:,2],   
    y=filtered.iloc[:,3],  
    hue=filtered.iloc[:,1],
    ci="sd"                 
)

plt.xlabel("Флаг оптимизации")
plt.title("Среднее время работы для 100 генераций вычисления множества Мандельброта")
plt.show()
# Out:
# /tmp/ipykernel_7711/1684011283.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## G++ vs clang++ флаг -О2
#
# На данном уровне оптимизации clang++ работает быстрее из-за развертки циклов
#
# g++ :
#
# <img src="godbolt_img/3.png" width="80%">
#
# clang++:
#
# <img src="godbolt_img/3c.png" width="80%">
#
# Для флага оптимизации -O3 аналогично -О2 (оба компилятора генерируют почти идентичный код)

# %% [markdown]
# # Полная таблица сравнений доверительных интервалов всех реализаций

# %% [markdown]
# | Компилятор/Оптимизация |          Naive            |          Array            |          SIMD             |
# |------------------------|---------------------------|---------------------------|---------------------------|
# | g++ -O2                | 4.0892 (+- 0.0005)   | 1.649 (+- 0.002)   | 1.248 (+- 0.003)   |
# | g++ -O3                | 4.0895 (+- 0.0004)   | 2.077 (+- 0.001)   | 1.249 (+- 0.001)  |
# | clang++ -O2            | 4.0261 (+- 0.0004)   | 1.4985 (+- 0.0006)   | 1.2306 (+- 0.0007)   |
# | clang++ -O3            | 4.0264 (+- 0.0005)   | 1.4982 (+- 0.0007)  | 1.2308 (+- 0.0006)   |

# %% [markdown]
# # Доказательство отсутствия тротлинга при замерах

# %% [markdown]
# Все тесты выполнялись на базовой тактовой частоте P‑ядер Intel Core Ultra 9, равной 2.9 ГГц. На графиках заметны кратковременные скачки частоты до 4.7 ГГц в конце замеров. Чтобы обеспечить стабильную работу на базовой частоте 2.9 ГГц под нагрузкой, пришлось вручную задать рекомендуемую частоту через
#
# ```zsh
# sudo cpupower frequency-set -d <num>GHz
# sudo cpupower frequency-set -u <num>GHz
# ```
#
# в диапазоне 4.7–4.9 ГГц. Это связано с тем, что драйвер intel_pstate позволяет выставлять только рекомендуемую (target) частоту. В результате при нагрузке процессор автоматически снижал её до требуемых 2.9 ГГц, что обеспечивало корректные условия тестирования.

# %% [markdown]
# ## Наивная реализация
#
# ### G++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_141645.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_141932.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_142217.png" width="60%">
#
#
# ### Clang++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_142508.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_142749.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_143031.png" width="60%">
#
#
# ### G++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_143329.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_143609.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_143852.png" width="60%">
#
#
# ### Clang++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_144202.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_144444.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_144726.png" width="60%">

# %% [markdown]
# ## Реализация на массивах
#
# ### G++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_144922.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_145033.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_145147.png" width="60%">
#
#
# ### Clang++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_145305.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_145411.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_145518.png" width="60%">
#
#
# ### G++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_145703.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_145830.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_145958.png" width="60%">
#
#
# ### Clang++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_150124.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_150230.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_150336.png" width="60%">

# %% [markdown]
# ## SIMD Реализация
#
# ### G++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_150451.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_150548.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_150806.png" width="60%">
#
#
# ### Clang++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_150911.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_151024.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_151122.png" width="60%">
#
#
# ### G++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_151238.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_151335.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_151432.png" width="60%">
#
#
# ### Clang++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_151539.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_151636.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_151731.png" width="60%">
