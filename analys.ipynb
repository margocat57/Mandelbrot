# %% [markdown]
# # Анализ оптимизаций алгоритма построения множества Мальдеброта

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

df = pd.read_csv("results.csv", header=None, sep=";")

# %% [markdown]
# ## Наивная реализация запуск на g++ (-O2)

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O2)")
plt.show()

# %%
subset1_2_g = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++" )
]

subset1_2_g.describe()
# Out:
#                3
# count  90.000000
# mean    4.581399
# std     0.016124
# min     4.561090
# 25%     4.566963
# 50%     4.579155
# 75%     4.591500
# max     4.629160

# %%
mean = np.mean(subset1_2_g.iloc[:,3])
std = np.std(subset1_2_g.iloc[:,3], ddof=1)
n = len(subset1_2_g.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 4.578068161109595 4.584730727779293

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (g++ -O2) от 4.58 до 4.58 секунд, среднее время работы 4.58 секунд

# %% [markdown]
# ## Наивная реализация запуск на clang++ (-O2)

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O2)")
plt.show()

# %%
subset1_2_c = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++" )
]

subset1_2_c.describe()
# Out:
#                3
# count  90.000000
# mean    4.516824
# std     0.020691
# min     4.489950
# 25%     4.500447
# 50%     4.513890
# 75%     4.527380
# max     4.589170

# %%
mean = np.mean(subset1_2_c.iloc[:,3])
std = np.std(subset1_2_c.iloc[:,3], ddof=1)
n = len(subset1_2_c.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 4.512549109455673 4.521098668322104

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (clang++ -O2) от 4.51 до 4.52 секунд, среднее время работы 4.52 секунд

# %% [markdown]
# ## Наивная реализация запуск на g++ (-O3)

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O3)")
plt.show()

# %%
subset1_3_g = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++" )
]

subset1_3_g.describe()
# Out:
#                3
# count  90.000000
# mean    4.591074
# std     0.021427
# min     4.562010
# 25%     4.576422
# 50%     4.586630
# 75%     4.602267
# max     4.652680

# %%
mean = np.mean(subset1_3_g.iloc[:,3])
std = np.std(subset1_3_g.iloc[:,3], ddof=1)
n = len(subset1_3_g.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 4.586647309124529 4.595500913097694

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (g++ -O3) от 4.59 до 4.60 секунд, среднее время работы 4.59 секунд

# %% [markdown]
# ## Наивная реализация запуск на clang++ (-O3)

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O3)")
plt.show()

# %%
subset1_3_c = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++" )
]


subset1_3_c.describe()
# Out:
#                3
# count  90.000000
# mean    4.510389
# std     0.016839
# min     4.490240
# 25%     4.497853
# 50%     4.507305
# 75%     4.516348
# max     4.575550

# %%
mean = np.mean(subset1_3_c.iloc[:,3])
std = np.std(subset1_3_c.iloc[:,3], ddof=1)
n = len(subset1_3_c.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 4.506909956710176 4.513867598845378

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (clang++ -O2) от 4.51 до 4.51 секунд, среднее время работы 4.51 секунд

# %% [markdown]
# ### Сравнение всех оптимизаций для наивной реализации

# %% [markdown]
# | Компилятор/Оптимизация | Naive |
# |------------------------|---------------|
# | g++ -O2                |  4.58 (+- 0.02)    |
# | g++ -O3                |  4.59 (+- 0.02)  |
# | clang++ -O2            |  4.52 (+- 0.02)    |
# | clang++ -O3            |  4.51 (+- 0.02)    |

# %%
filtered = df[df.iloc[:,0] == "mandelbrot1"]

sns.barplot(
    data=filtered,
    x=filtered.iloc[:,2],   
    y=filtered.iloc[:,3],  
    hue=filtered.iloc[:,1],
    ci="sd"                 
)

plt.xlabel("Флаг оптимизации")
plt.title("Среднее время работы для 100 генераций вычисления множества Мандельброта")
plt.show()
# Out:
# /tmp/ipykernel_3000/302414564.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # Объяснение разницы работы реализаций
#
# ## G++ vs clang++ флаг -О2
#
# Основное различие заключается в том, что g++ не разворачивает циклы, а clang++ - разворачивает.
#
# g++ :
#
# <img src="godbolt_img/1_2.png" width="80%">
#
# clang++:
#
# <img src="godbolt_img/1_2_cyc.png" width="80%">
#
# Также g++ более экономно использует регистры и сильнее обращается память (даже внутри циклов) в отличие от clang++ - он сильнее использует регистры, а все обращение в память старается вынести вне циклов. Особенно это можно видеть если посмотреть на ассемберный код, сгенерированный компиляторами для
# ```c
# double y0 = ((i_for_y - (double)SUPER_HEIGHT / 2) * DY) * SCALE_Y * params->zoom + params->center_y;
# ```
#
# g++ :
#
# <img src="godbolt_img/1_1gcc.png" width="80%">
#
# clang++:
#
# <img src="godbolt_img/1_1clang.png" width="80%">
#
# ## G++ и clang++ -O3 vs -O2
#
# Различий нет, так как код, сгенерированный при данных оптимизациях не отличается от кода сгенерированного при -О2. Однако

# %% [markdown]
# ## Реализация на массивах запуск на g++ с флагом -O2

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O2)")
plt.show()

# %%
subset2_2_g = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++" )
]

subset2_2_g.describe()
# Out:
#                3
# count  90.000000
# mean    1.850853
# std     0.012057
# min     1.834430
# 25%     1.841413
# 50%     1.847105
# 75%     1.860208
# max     1.886750

# %%
mean = np.mean(subset2_2_g.iloc[:,3])
std = np.std(subset2_2_g.iloc[:,3], ddof=1)
n = len(subset2_2_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.8483623138880727 1.8533443527785942

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (g++ -O2) от 1.85 до 1.85 секунд, среднее время работы 1.85 секунд

# %% [markdown]
# ## Реализация на массивах запуск на clang++ с флагом -O2

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O2)")
plt.show()

# %%
subset2_2_c = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++" )
]

subset2_2_c.describe()
# Out:
#                3
# count  90.000000
# mean    1.684695
# std     0.012826
# min     1.670910
# 25%     1.675177
# 50%     1.680795
# 75%     1.689980
# max     1.719450

# %%
mean = np.mean(subset2_2_c.iloc[:,3])
std = np.std(subset2_2_c.iloc[:,3], ddof=1)
n = len(subset2_2_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.6820448334025644 1.6873444999307685

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (clang++ -O2) от 1.68 до 1.69 секунд, среднее время работы 1.68 секунд

# %% [markdown]
# ## Реализация на массивах запуск на g++ с флагом -O3

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O3)")
plt.show()

# %%
subset2_3_g = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++" )
]

subset2_3_g.describe()
# Out:
#                3
# count  90.000000
# mean    2.329522
# std     0.014909
# min     2.314330
# 25%     2.316908
# 50%     2.324625
# 75%     2.337345
# max     2.384460

# %%
mean = np.mean(subset2_3_g.iloc[:,3])
std = np.std(subset2_3_g.iloc[:,3], ddof=1)
n = len(subset2_3_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 2.326442221118968 2.3326026677699203

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (g++ -O3) от 2.33 до 2.33 секунд, среднее время работы 2.33 секунд

# %% [markdown]
# ## Реализация на массивах запуск на clang++ с флагом -O3

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O3)")
plt.show()

# %%
subset2_3_c = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++" )
]

subset2_3_c.describe()
# Out:
#                3
# count  90.000000
# mean    1.686163
# std     0.016453
# min     1.670500
# 25%     1.674515
# 50%     1.681905
# 75%     1.692620
# max     1.759610

# %%
mean = np.mean(subset2_3_c.iloc[:,3])
std = np.std(subset2_3_c.iloc[:,3], ddof=1)
n = len(subset2_3_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.6827634121803023 1.6895616989308087

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (clang++ -O3) от 1.68 до 1.69 секунд, среднее время работы 1.69 секунд

# %% [markdown]
# ### Сравнений всех оптимизаций для реализации на массивах

# %% [markdown]
# | Компилятор/Оптимизация | Array |
# |------------------------|---------------|
# | g++ -O2                |  1.85 (+- 0.01)  |
# | g++ -O3                |  1.68 (+- 0.01)     |
# | clang++ -O2            |  2.33 (+- 0.01)    |
# | clang++ -O3            |  1.69 (+- 0.02)    |

# %%
filtered = df[df.iloc[:,0] == "mandelbrot2"]

sns.barplot(
    data=filtered,
    x=filtered.iloc[:,2],   
    y=filtered.iloc[:,3],  
    hue=filtered.iloc[:,1],
    ci="sd"                 
)

plt.xlabel("Флаг оптимизации")
plt.title("Среднее время работы для 100 генераций вычисления множества Мандельброта")
plt.show()
# Out:
# /tmp/ipykernel_3000/193063319.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # Объяснение разницы работы реализаций
#
# ## G++ vs clang++ флаг -О2
#
# Clang++ активнее использует fma и simd инструкции и меньше обращается к памяти в циклах, например для
#
# ```c
# for(int j = 0; j < 4; j++){x0[j]= X0 + j*dx;};
# ```
#
# clang++ заменил на SIMD вариант, а g++ - нет и при этом обращается в память.
#
# g++ :
#
# <img src="godbolt_img/2_2gcc.png" width="80%">
#
# clang++:
#
# <img src="godbolt_img/2_2clang.png" width="80%">
#
# Также clang++ на данном уровне оптимизации развернул циклы в отличие от g++
#
# g++ :
#
# <img src="godbolt_img/2_3gcc.png" width="80%">
#
# clang++:
#
# <img src="godbolt_img/2_3clang.png" width="80%">
#
# ## G++ -O2 vs g++ -О3
#
# Intrinsic инструкции стали применяться реже, также стало больше обращений в память, примеры на скриншотах. Например, для
#
# ```c
# for(int j = 0; j < 4; j++){x2[j]= x[j] * x[j];}  (1)
#
# for(int j = 0; j < 4; j++){y2[j]= y[j] * y[j];}
# ```
# g++ на уровне оптимизации -O3 заменил одну intrinsic инструкцию на 4 умножения и одно обращения в память
#
# g++ -O2 :
#
# <img src="godbolt_img/2_4gcc.png" width="80%">
#
# g++ -O3 :
#
# <img src="godbolt_img/2_4c.png" width="80%">

# %% [markdown]
# ## Реализация SIMD запуск на g++ с флагом -O2

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O2)")
plt.show()

# %%
subset3_2_g = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++" )
]


subset3_2_g.describe()
# Out:
#                3
# count  90.000000
# mean    1.402321
# std     0.012207
# min     1.390780
# 25%     1.391807
# 50%     1.397925
# 75%     1.406985
# max     1.439740

# %%
mean = np.mean(subset3_2_g.iloc[:,3])
std = np.std(subset3_2_g.iloc[:,3], ddof=1)
n = len(subset3_2_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.3997993062928584 1.4048433603738082

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(g++ -O2) от 1.40 до 1.40 секунд, среднее время работы 1.40 секунд

# %% [markdown]
# ## Реализация SIMD запуск на clang++ с флагом -O2

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O2)")
plt.show()

# %%
subset3_2_c = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++" )
]

subset3_2_c.describe()
# Out:
#                3
# count  90.000000
# mean    1.378329
# std     0.007247
# min     1.370260
# 25%     1.372440
# 50%     1.375115
# 75%     1.384025
# max     1.398670

# %%
mean = np.mean(subset3_2_c.iloc[:,3])
std = np.std(subset3_2_c.iloc[:,3], ddof=1)
n = len(subset3_2_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.3768317545361732 1.3798260232416046

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(clang++ -O2) от 1.377 до 1.340 секунд, среднее время работы 1.378 секунд

# %% [markdown]
# ## Реализация SIMD запуск на g++ с флагом -O3

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O3)")
plt.show()

# %%
subset3_3_g = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++" )
]

subset3_3_g.describe()
# Out:
#                3
# count  90.000000
# mean    1.405354
# std     0.012299
# min     1.391120
# 25%     1.394955
# 50%     1.403880
# 75%     1.410308
# max     1.449570

# %%
mean = np.mean(subset3_3_g.iloc[:,3])
std = np.std(subset3_3_g.iloc[:,3], ddof=1)
n = len(subset3_3_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.4028133199122397 1.4078951245322047

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(g++ -O3) от 1.40 до 1.41 секунд, среднее время работы 1.41 секунд

# %% [markdown]
# ## Реализация SIMD запуск на clang++ с флагом -O3

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++")
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O3)")
plt.show()

# %%
subset3_3_c = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++" )
]

subset3_3_c.describe()
# Out:
#                3
# count  90.000000
# mean    1.381775
# std     0.014085
# min     1.372040
# 25%     1.372583
# 50%     1.375470
# 75%     1.385683
# max     1.445130

# %%
mean = np.mean(subset3_3_c.iloc[:,3])
std = np.std(subset3_3_c.iloc[:,3], ddof=1)
n = len(subset3_3_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.3788648899844842 1.3846848877932934

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(clang++ -O3) от 1.38 до 1.38 секунд, среднее время работы 1.38 секунд

# %% [markdown]
# ### Сравнений всех оптимизаций для SIMD реализации

# %% [markdown]
# | Компилятор/Оптимизация |         SIMD             |
# |------------------------|---------------------------|
# | g++ -O2                | 1.40 (+- 0.01)  |
# | g++ -O3                | 1.378 (+- 0.007)  |
# | clang++ -O2            | 1.41 (+- 0.01) |
# | clang++ -O3            | 1.38 (+- 0.01)  |

# %%
filtered = df[df.iloc[:,0] == "mandelbrot3"]

sns.barplot(
    data=filtered,
    x=filtered.iloc[:,2],   
    y=filtered.iloc[:,3],  
    hue=filtered.iloc[:,1],
    ci="sd"                 
)

plt.xlabel("Флаг оптимизации")
plt.title("Среднее время работы для 100 генераций вычисления множества Мандельброта")
plt.show()
# Out:
# /tmp/ipykernel_3000/1684011283.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## G++ vs clang++ флаг -О2
#
# На данном уровне оптимизации clang++ работает быстрее из-за развертки циклов
#
# g++ :
#
# <img src="godbolt_img/3.png" width="80%">
#
# clang++:
#
# <img src="godbolt_img/3c.png" width="80%">
#
# Для флага оптимизации -O3 аналогично -О2 (оба компилятора генерируют почти идентичный код)

# %% [markdown]
# # Полная таблица сравнений доверительных интервалов всех реализаций

# %% [markdown]
# | Компилятор/Оптимизация |          Naive            |          Array            |          SIMD             |
# |------------------------|---------------------------|---------------------------|---------------------------|
# | g++ -O2                | 4.58 (+- 0.02)   | 1.85 (+- 0.01)   | 1.40 (+- 0.01)   |
# | g++ -O3                | 4.59 (+- 0.02)   | 1.68 (+- 0.01)   | 1.378 (+- 0.007)  |
# | clang++ -O2            | 4.52 (+- 0.02)   | 2.33 (+- 0.01)   | 1.41 (+- 0.01)   |
# | clang++ -O3            | 4.51 (+- 0.02)   | 1.69 (+- 0.02)  | 1.38 (+- 0.01)   |

# %% [markdown]
# # Доказательство отсутствия тротлинга при замерах

# %% [markdown]
# ## Наивная реализация
#
# ### G++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260413_231523.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260413_231835.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260413_232140.png" width="60%">
#
#
# ### Clang++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260413_232449.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260413_232749.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260413_233046.png" width="60%">
#
#
# ### G++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260413_233412.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260413_233722.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260413_234036.png" width="60%">
#
#
# ### Clang++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260413_234348.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260413_234646.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260413_234943.png" width="60%">

# %% [markdown]
# ## Реализация на массивах
#
# ### G++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260413_235125.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260413_235303.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260413_235430.png" width="60%">
#
#
# ### Clang++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260413_235554.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260413_235710.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260413_235825.png" width="60%">
#
#
# ### G++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_000054.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_000231.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_000405.png" width="60%">
#
#
# ### Clang++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_000640.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_000957.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_001110.png" width="60%">

# %% [markdown]
# ## SIMD Реализация
#
# ### G++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_001425.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_001540.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_001641.png" width="60%">
#
#
# ### Clang++ -O2
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_001757.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_001859.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_002000.png" width="60%">
#
#
# ### G++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_002115.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_002217.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_002320.png" width="60%">
#
#
# ### Clang++ -O3
#
# ##### Тест 1:
#
# <img src="tests_img/Screenshot_20260414_002435.png" width="60%">
#
# ##### Тест 2:
#
# <img src="tests_img/Screenshot_20260414_002536.png" width="60%">
#
# ##### Тест 3:
# <img src="tests_img/Screenshot_20260414_002636.png" width="60%">
