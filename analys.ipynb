# %% [markdown]
# # Анализ оптимизаций алгоритма построения множества Мальдеброта

# %% [markdown]
# ## Наивная реализация запуск на g++ (-O1)

# %%
import pandas as pd

df = pd.read_csv("results.csv", header=None, sep=";")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O1") &
    (df.iloc[:,1].isin(["clang++", "g++"]))
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O1)")
plt.show()

# %%
subset1_1_g = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O1") &
    (df.iloc[:,1] == "g++" )
]

subset1_1_g.describe()
# Out:
#                 3
# count  100.000000
# mean     5.703194
# std      0.151879
# min      4.401640
# 25%      5.722300
# 50%      5.724115
# 75%      5.725000
# max      5.734960

# %%
import numpy as np
from scipy.stats import norm

mean = np.mean(subset1_1_g.iloc[:,3])
std = np.std(subset1_1_g.iloc[:,3], ddof=1)
n = len(subset1_1_g.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 5.673426053467291 5.732961546532709

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (g++ -O1) от 5.67 до 5.73 секунд, среднее время работы 5.70 секунд

# %% [markdown]
# ## Наивная реализация запуск на clang++ (-O1)

# %%
subset1_1_c = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O1") &
    (df.iloc[:,1] == "clang++" )
]

subset1_1_c.describe()
# Out:
#                 3
# count  100.000000
# mean     5.694111
# std      0.140128
# min      4.963420
# 25%      5.720675
# 50%      5.722720
# 75%      5.723782
# max      5.735300

# %%
mean = np.mean(subset1_1_c.iloc[:,3])
std = np.std(subset1_1_c.iloc[:,3], ddof=1)
n = len(subset1_1_c.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 5.666646560696898 5.721575839303102

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (clang++ -O1) от 5.67 до 5.72 секунд, среднее время работы 5.69 секунд

# %% [markdown]
# ## Наивная реализация запуск на g++ (-O2)

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1].isin(["clang++", "g++"]))
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O2)")
plt.show()

# %%
subset1_2_g = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++" )
]

subset1_2_g.describe()
# Out:
#                 3
# count  100.000000
# mean     5.173949
# std      0.148481
# min      3.704380
# 25%      5.188050
# 50%      5.188140
# 75%      5.188220
# max      5.212150

# %%
mean = np.mean(subset1_2_g.iloc[:,3])
std = np.std(subset1_2_g.iloc[:,3], ddof=1)
n = len(subset1_2_g.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 5.144847526027087 5.203050873972909

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (g++ -O2) от 5.14 до 5.20 секунд, среднее время работы 5.17 секунд

# %% [markdown]
# ## Наивная реализация запуск на clang++ (-O2)

# %%
subset1_2_c = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++" )
]

subset1_2_c.describe()
# Out:
#                 3
# count  100.000000
# mean     5.098496
# std      0.092860
# min      4.342270
# 25%      5.110968
# 50%      5.111145
# 75%      5.111355
# max      5.122810

# %%
mean = np.mean(subset1_2_c.iloc[:,3])
std = np.std(subset1_2_c.iloc[:,3], ddof=1)
n = len(subset1_2_c.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 5.080296268878544 5.116696731121455

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (clang++ -O2) от 5.08 до 5.12 секунд, среднее время работы 5.10 секунд

# %% [markdown]
# ## Наивная реализация запуск на g++ (-O3)

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1].isin(["clang++", "g++"]))
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для наивной реализации (флаг -O3)")
plt.show()

# %%
subset1_3_g = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++" )
]

subset1_3_g.describe()
# Out:
#                 3
# count  100.000000
# mean     5.180437
# std      0.073067
# min      4.458100
# 25%      5.186145
# 50%      5.187570
# 75%      5.187993
# max      5.217640

# %%
mean = np.mean(subset1_3_g.iloc[:,3])
std = np.std(subset1_3_g.iloc[:,3], ddof=1)
n = len(subset1_3_g.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 5.166115755092302 5.1947574449076965

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (g++ -O3) от 5.17 до 5.19 секунд, среднее время работы 5.18 секунд

# %% [markdown]
# ## Наивная реализация запуск на clang++ (-O3)

# %%
subset1_3_c = df[
    (df.iloc[:,0] == "mandelbrot1") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++" )
]


subset1_3_c.describe()
# Out:
#                 3
# count  100.000000
# mean     5.094485
# std      0.107103
# min      4.244320
# 25%      5.108512
# 50%      5.108780
# 75%      5.109122
# max      5.128440

# %%
mean = np.mean(subset1_3_c.iloc[:,3])
std = np.std(subset1_3_c.iloc[:,3], ddof=1)
n = len(subset1_3_c.iloc[:,3])

alpha = 0.05 
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 5.0734929010858 5.1154764989142

# %% [markdown]
# ### Доверительный интервал времени работы обычной реализации (clang++ -O2) от 5.07 до 5.12 секунд, среднее время работы 5.09 секунд

# %% [markdown]
# ## Реализация на массивах запуск на g++ с флагом -O1

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O1") &
    (df.iloc[:,1].isin(["clang++", "g++"]))
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O1)")
plt.show()

# %%
subset2_1_g = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O1") &
    (df.iloc[:,1] == "g++" )
]

subset2_1_g.describe()
# Out:
#                 3
# count  100.000000
# mean    10.172022
# std      0.180449
# min      9.139660
# 25%     10.096725
# 50%     10.099500
# 75%     10.408025
# max     10.425800

# %%
mean = np.mean(subset2_1_g.iloc[:,3])
std = np.std(subset2_1_g.iloc[:,3], ddof=1)
n = len(subset2_1_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 10.136654275296051 10.20738892470395

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (g++ -O1) от 10.1 до 10.2 секунд, среднее время работы 10.2 секунд

# %% [markdown]
# ## Реализация на массивах запуск на clang++ с флагом -O1

# %%
subset2_1_c = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O1") &
    (df.iloc[:,1] == "clang++" )
]
subset2_1_c.describe()
# Out:
#                 3
# count  100.000000
# mean    10.422382
# std      0.272438
# min      8.940070
# 25%     10.449475
# 50%     10.452050
# 75%     10.457150
# max     10.809800

# %%
mean = np.mean(subset2_1_c.iloc[:,3])
std = np.std(subset2_1_c.iloc[:,3], ddof=1)
n = len(subset2_1_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 10.368985137995391 10.47577886200461

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (clang++ -O1) от 10.4 до 10.5 секунд, среднее время работы 10.4 секунд

# %% [markdown]
# ## Реализация на массивах запуск на g++ с флагом -O2

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1].isin(["clang++", "g++"]))
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O2)")
plt.show()

# %%
subset2_2_g = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++" )
]

subset2_2_g.describe()
# Out:
#                 3
# count  100.000000
# mean     2.043716
# std      0.020069
# min      1.851400
# 25%      2.041648
# 50%      2.046645
# 75%      2.047067
# max      2.077160

# %%
mean = np.mean(subset2_2_g.iloc[:,3])
std = np.std(subset2_2_g.iloc[:,3], ddof=1)
n = len(subset2_2_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 2.0397830576245357 2.047649942375464

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (g++ -O2) от 2.04 до 2.05 секунд, среднее время работы 2.04 секунд

# %% [markdown]
# ## Реализация на массивах запуск на clang++ с флагом -O2

# %%
subset2_2_c = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++" )
]

subset2_2_c.describe()
# Out:
#                 3
# count  100.000000
# mean     2.040191
# std      0.041666
# min      1.634030
# 25%      2.041478
# 50%      2.046085
# 75%      2.047073
# max      2.058580

# %%
mean = np.mean(subset2_2_c.iloc[:,3])
std = np.std(subset2_2_c.iloc[:,3], ddof=1)
n = len(subset2_2_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 2.0320241648502617 2.0483568351497383

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (clang++ -O2) от 2.03 до 2.05 секунд, среднее время работы 2.04 секунд

# %% [markdown]
# ## Реализация на массивах запуск на g++ с флагом -O3

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1].isin(["clang++", "g++"]))
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для реализации на массивах (флаг -O3)")
plt.show()

# %%
subset2_3_g = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++" )
]

subset2_3_g.describe()
# Out:
#                 3
# count  100.000000
# mean     2.629673
# std      0.004414
# min      2.626150
# 25%      2.628138
# 50%      2.628950
# 75%      2.629755
# max      2.667350

# %%
mean = np.mean(subset2_3_g.iloc[:,3])
std = np.std(subset2_3_g.iloc[:,3], ddof=1)
n = len(subset2_3_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 2.6288075254841834 2.6305378745158174

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (g++ -O3) от 2.629 до 2.630 секунд, среднее время работы 2.630 секунд

# %% [markdown]
# ## Реализация на массивах запуск на clang++ с флагом -O3

# %%
subset2_3_c = df[
    (df.iloc[:,0] == "mandelbrot2") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++" )
]

subset2_3_c.describe()
# Out:
#                 3
# count  100.000000
# mean     1.846256
# std      0.122309
# min      1.239130
# 25%      1.888670
# 50%      1.888995
# 75%      1.891170
# max      1.913670

# %%
mean = np.mean(subset2_3_c.iloc[:,3])
std = np.std(subset2_3_c.iloc[:,3], ddof=1)
n = len(subset2_3_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.8222840263334366 1.8702283736665635

# %% [markdown]
# ### Доверительный интервал времени работы реализации на массивах (clang++ -O3) от 1.82 до 1.87 секунд, среднее время работы 1.85 секунд

# %% [markdown]
# ## Реализация SIMD запуск на g++ с флагом -O1

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O1") &
    (df.iloc[:,1].isin(["clang++", "g++"]))
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O1)")
plt.show()

# %%
subset3_1_g = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O1") &
    (df.iloc[:,1] == "g++" )
]

subset3_1_g.describe()
# Out:
#                 3
# count  100.000000
# mean     1.979164
# std      0.003504
# min      1.974500
# 25%      1.976527
# 50%      1.979390
# 75%      1.980412
# max      1.997690

# %%
mean = np.mean(subset3_1_g.iloc[:,3])
std = np.std(subset3_1_g.iloc[:,3], ddof=1)
n = len(subset3_1_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.978477822899157 1.979851177100843

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(g++ -O1) от 1.978 до 1.980 секунд, среднее время работы 1.979 секунд

# %% [markdown]
# ## Реализация SIMD запуск на clang++ с флагом -O1

# %%
subset3_1_c = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O1") &
    (df.iloc[:,1] == "clang++" )
]

subset3_1_c.describe()
# Out:
#                 3
# count  100.000000
# mean     1.498715
# std      0.142628
# min      0.784263
# 25%      1.535708
# 50%      1.536020
# 75%      1.536975
# max      1.554320

# %%
mean = np.mean(subset3_1_c.iloc[:,3])
std = np.std(subset3_1_c.iloc[:,3], ddof=1)
n = len(subset3_1_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.4707605101380214 1.5266695498619791

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(clang++ -O1) от 1.47 до 1.52 секунд, среднее время работы 1.50 секунд

# %% [markdown]
# ## Реализация SIMD запуск на g++ с флагом -O2

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1].isin(["clang++", "g++"]))
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O2)")
plt.show()

# %%
subset3_2_g = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "g++" )
]


subset3_2_g.describe()
# Out:
#                 3
# count  100.000000
# mean     1.982363
# std      0.003086
# min      1.981350
# 25%      1.981520
# 50%      1.981620
# 75%      1.981807
# max      2.005810

# %%
mean = np.mean(subset3_2_g.iloc[:,3])
std = np.std(subset3_2_g.iloc[:,3], ddof=1)
n = len(subset3_2_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.981758067072068 1.9829679329279313

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(g++ -O2) от 1.981 до 1.983 секунд, среднее время работы 1.982 секунд

# %% [markdown]
# ## Реализация SIMD запуск на clang++ с флагом -O2

# %%
subset3_2_c = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O2") &
    (df.iloc[:,1] == "clang++" )
]

subset3_2_c.describe()
# Out:
#                 3
# count  100.000000
# mean     1.557239
# std      0.003710
# min      1.554720
# 25%      1.555525
# 50%      1.556305
# 75%      1.557417
# max      1.582550

# %%
mean = np.mean(subset3_2_c.iloc[:,3])
std = np.std(subset3_2_c.iloc[:,3], ddof=1)
n = len(subset3_2_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.55651149268244 1.5579659073175602

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(clang++ -O2) от 1.557 до 1.558 секунд, среднее время работы 1.557 секунд

# %% [markdown]
# ## Реализация SIMD запуск на g++ с флагом -O3

# %%
filtered = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1].isin(["clang++", "g++"]))
]

sns.kdeplot(
    data=filtered,
    x=filtered.iloc[:,3],
    hue=filtered.iloc[:,1],
    fill=True,           
    alpha=0.3,           
    linewidth=2          
)

plt.xlabel("Время работы для 100 генераций")
plt.ylabel("Плотность")
plt.title("Распределение времени вычисления множества Мандельброта для SIMD реализации(флаг -O3)")
plt.show()

# %%
subset3_3_g = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "g++" )
]

subset3_3_g.describe()
# Out:
#                 3
# count  100.000000
# mean     1.983195
# std      0.003562
# min      1.981820
# 25%      1.982180
# 50%      1.982350
# 75%      1.982875
# max      2.013310

# %%
mean = np.mean(subset3_3_g.iloc[:,3])
std = np.std(subset3_3_g.iloc[:,3], ddof=1)
n = len(subset3_3_g.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)
# Out:
# Доверительный интервал:
# 1.9824965568976627 1.9838926431023374

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(g++ -O3) от 1.982 до 1.984 секунд, среднее время работы 1.983 секунд

# %% [markdown]
# ## Реализация SIMD запуск на clang++ с флагом -O3

# %%
subset3_3_c = df[
    (df.iloc[:,0] == "mandelbrot3") &
    (df.iloc[:,2] == "O3") &
    (df.iloc[:,1] == "clang++" )
]

subset3_3_c.describe()
# Out:
#                 3
# count  100.000000
# mean     1.556844
# std      0.004410
# min      1.554480
# 25%      1.555508
# 50%      1.555855
# 75%      1.556318
# max      1.591040

# %%
mean = np.mean(subset3_3_c.iloc[:,3])
std = np.std(subset3_3_c.iloc[:,3], ddof=1)
n = len(subset3_3_c.iloc[:,3])

alpha = 0.05  
z = norm.ppf(1 - alpha/2)

lower = mean - z * std / np.sqrt(n)
upper = mean + z * std / np.sqrt(n)

print("Доверительный интервал:")
print(lower, upper)

1.432
0.001
# Out:
# Доверительный интервал:
# 1.5559797857778586 1.557708614222142
# 0.001

# %% [markdown]
# ### Доверительный интервал времени работы SIMD реализации(clang++ -O3) от 1.556 до 1.558 секунд, среднее время работы 1.557 секунд

# %% [markdown]
# # Полная таблица сравнений доверительных интервалов всех реализаций

# %% [markdown]
# | Компилятор/Оптимизация |          Naive            |          Array            |          SIMD             |
# |------------------------|---------------------------|---------------------------|---------------------------|
# | g++ -O1                | [ 5.67 - 5.73 ]   | [ 10.1 - 10.2 ]   | [ 1.978 - 1.980 ]   |
# | g++ -O2                | [ 5.14 - 5.20 ]   | [ 2.04 - 2.05 ]   | [ 1.981 - 1.983 ]   |
# | g++ -O3                | [ 5.17 - 5.19 ]   | [ 2.629 - 2.630 ]   | [ 1.982 - 1.984 ]   |
# | clang++ -O1            | [ 5.67 - 5.72 ]   | [ 10.4 - 10.5 ]   | [ 1.47 - 1.52 ]   |
# | clang++ -O2            | [ 5.08 - 5.12 ]   | [ 2.03 - 2.05 ]   | [ 1.557 - 1.558 ]   |
# | clang++ -O3            | [ 5.07 - 5.12 ]   | [ 1.82 - 1.87 ]   | [ 1.556 - 1.5583 ]   |
